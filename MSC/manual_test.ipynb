# %%
import numpy as np
from scipy import sparse

# %%
PATH = "/home/daniel/Projects/Python/task1-irl/MSC/parsed_replays/GlobalFeatureVector/Terran_vs_Terran/Terran/1@000a4ab29a10c7db1e2e7d0dcde9aad01fb297a703417c03e4a5137c0fb2af0d.SC2Replay.npz"
features = np.asarray(sparse.load_npz(PATH).todense())

# %%
np.shape(features)
# Out:
# (1227, 753)

# %%
features[0]
# Out:
# array([1.00000000e+00, 7.40000000e+01, 1.05000000e+03, 1.06250000e+00,
#        0.00000000e+00, 6.00000000e+02, 4.00000000e+02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.04893271e-04,
#        7.51235783e-04, 0.00000000e+00, 7.50000000e-02, 6.00000000e-02,
#        0.00000000e+00, 6.00000000e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...
